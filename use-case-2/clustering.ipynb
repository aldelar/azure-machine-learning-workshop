# %%
# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
from azureml.core import Workspace, Dataset

subscription_id = 'c5ec24ce-9c5f-4da2-bf12-9ca8e9758d60'
resource_group = 'azure-ml-workshop'
workspace_name = 'agd-mlws'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='clustering-congestion-price')
dataset.to_pandas_dataframe()
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code BG4KKKUV8 to authenticate.
# Interactive authentication successfully completed.
#                                                        Path       date  he  \
# 0         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   1
# 1         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   2
# 2         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   3
# 3         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   4
# 4         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   5
# 5         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   6
# 6         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   7
# 7         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   8
# 8         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01   9
# 9         Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  10
# 10        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  11
# 11        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  12
# 12        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  13
# 13        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  14
# 14        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  15
# 15        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  16
# 16        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  17
# 17        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  18
# 18        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  19
# 19        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  20
# 20        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  21
# 21        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  22
# 22        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  23
# 23        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-01  24
# 24        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-02   1
# 25        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-02   2
# 26        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-02   3
# 27        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-02   4
# 28        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-02   5
# 29        Clustering/Congestion-Price-Data-Anonymized.pa... 2017-01-02   6
# ...                                                     ...        ...  ..
# 17143023  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-14  19
# 17143024  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-14  20
# 17143025  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-14  21
# 17143026  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-14  22
# 17143027  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-14  23
# 17143028  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-14  24
# 17143029  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   1
# 17143030  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   2
# 17143031  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   3
# 17143032  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   4
# 17143033  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   5
# 17143034  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   6
# 17143035  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   7
# 17143036  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   8
# 17143037  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15   9
# 17143038  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  10
# 17143039  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  11
# 17143040  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  12
# 17143041  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  13
# 17143042  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  14
# 17143043  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  15
# 17143044  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  16
# 17143045  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  17
# 17143046  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  18
# 17143047  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  19
# 17143048  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  20
# 17143049  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  21
# 17143050  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  22
# 17143051  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  23
# 17143052  Clustering/Congestion-Price-Data-Anonymized.pa... 2019-09-15  24
#
#           interval      cong  node_number
# 0                1  0.000000         41.0
# 1                1  0.000000         41.0
# 2                1  0.000000         41.0
# 3                1  0.000000         41.0
# 4                1  0.000000         41.0
# 5                1  0.000000         41.0
# 6                1  0.000000         41.0
# 7                1 -0.064707         41.0
# 8                1 -0.051742         41.0
# 9                1 -1.640796         41.0
# 10               1 -2.616092         41.0
# 11               1 -3.174029         41.0
# 12               1 -3.317226         41.0
# 13               1 -3.352984         41.0
# 14               1 -2.516162         41.0
# 15               1 -0.051146         41.0
# 16               1 -0.021525         41.0
# 17               1  0.000000         41.0
# 18               1 -0.019717         41.0
# 19               1  0.000000         41.0
# 20               1  0.000000         41.0
# 21               1 -0.134869         41.0
# 22               1 -0.072070         41.0
# 23               1  0.000000         41.0
# 24               1  0.000000         41.0
# 25               1  0.000000         41.0
# 26               1  0.000000         41.0
# 27               1  0.000000         41.0
# 28               1  0.000000         41.0
# 29               1  0.000000         41.0
# ...            ...       ...          ...
# 17143023         1  0.000000        982.0
# 17143024         1  0.000000        982.0
# 17143025         1  0.000000        982.0
# 17143026         1  0.000000        982.0
# 17143027         1  0.000000        982.0
# 17143028         1  0.000000        982.0
# 17143029         1  0.000000        982.0
# 17143030         1  0.000000        982.0
# 17143031         1  0.000000        982.0
# 17143032         1  0.000000        982.0
# 17143033         1  0.000000        982.0
# 17143034         1  0.000000        982.0
# 17143035         1  0.000000        982.0
# 17143036         1  0.000000        982.0
# 17143037         1 -0.039739        982.0
# 17143038         1 -0.293306        982.0
# 17143039         1 -0.278713        982.0
# 17143040         1 -0.323876        982.0
# 17143041         1 -0.279111        982.0
# 17143042         1 -0.211863        982.0
# 17143043         1 -0.375631        982.0
# 17143044         1 -0.403809        982.0
# 17143045         1 -0.492643        982.0
# 17143046         1 -0.789064        982.0
# 17143047         1  0.000000        982.0
# 17143048         1  0.000000        982.0
# 17143049         1  0.000000        982.0
# 17143050         1  0.000000        982.0
# 17143051         1 -0.192968        982.0
# 17143052         1  0.000000        982.0
#
# [17143053 rows x 6 columns]
